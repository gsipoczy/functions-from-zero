# %% [markdown]
# <a href="https://colab.research.google.com/github/gsipoczy/functions-from-zero/blob/main/MLOps_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("The normal first statement")
# Out:
# The normal first statement

# %%
variable = 1

# %%
print(variable)
# Out:
# 1
